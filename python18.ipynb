# %% [markdown]
# ## Files in Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f=open('nvidia.txt','w')

# %%
pwd  #present work directory
# Out:
# 'C:\\Users\\acer'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 32B7-66C7
#
#  Directory of C:\Users\acer
#
# 11/10/2025  05:13 PM    <DIR>          .
# 12/23/2022  12:23 AM    <DIR>          ..
# 01/26/2024  11:15 PM    <DIR>          .anaconda
# 05/28/2024  08:20 AM    <DIR>          .android
# 09/13/2025  01:23 AM             6,660 .bash_history
# 10/06/2025  07:13 PM    <DIR>          .cache
# 11/08/2025  12:33 PM    <DIR>          .conda
# 01/26/2024  11:15 PM                25 .condarc
# 01/26/2024  11:15 PM    <DIR>          .continuum
# 09/13/2025  01:14 PM    <DIR>          .docker
# 07/17/2023  07:24 PM    <DIR>          .eclipse
# 04/03/2024  12:40 AM                16 .emulator_console_auth_token
# 05/16/2024  11:59 AM               188 .gitconfig
# 10/20/2025  11:59 AM    <DIR>          .gitlab
# 05/12/2024  03:14 PM    <DIR>          .gradle
# 05/21/2023  04:27 PM    <DIR>          .idlerc
# 11/10/2025  05:11 PM    <DIR>          .ipynb_checkpoints
# ...

# %%
# write mode
f.write("Hello All Welcome To Our Youtube Channel Datascience")
# Out:
# 52

# %%
f.close()

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f=open("nvidia.txt",'r')

# %%
f.read()
# Out:
# 'Hello All Welcome To Our Youtube Channel Datascience'

# %%
f = open('nvidia.txt','a')

# %%
f.write("Please Subscribe to our channel")
# Out:
# 31

# %%
f.close()

# %%
f=open("nvidia.txt",'r')

# %%
f.read()
# Out:
# 'Hello All Welcome To Our Youtube Channel DatasciencePlease Subscribe to our channel'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# 'Hello All Welcome To Our Youtube Channel DatasciencePlease Subscribe to our channel'

# %%
f.seek(1)
# Out:
# 1

# %%
f.readline()
# Out:
# 'ello All Welcome To Our Youtube Channel DatasciencePlease Subscribe to our channel'

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline()
# Out:
# 'Welcome To Our Youtube Channel DatasciencePlease Subscribe to our channel'

# %%
f.seek(0)
# Out:
# 0

# %%
for i in f:
    print(i)
# Out:
# Hello All Welcome To Our Youtube Channel DatasciencePlease Subscribe to our channel

# %%
import os

# %%
os.path.getsize('nvidia.txt')
# Out:
# 83

# %%
f.close()

# %%
os.remove('nvidia.txt')

# %%
f=open('nvidia4.txt','w')

# %%
f.write('Hello')
# Out:
# 5

# %%
f.close()

# %%
import shutil

# %%
shutil.copy('nvidia4.txt','new.txt')
# Out:
# 'new.txt'

# %%
f=open("new.txt",'r')

# %%
f.read()
# Out:
# 'Hello'
