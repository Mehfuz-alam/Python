# %% [markdown]
# ## Comprehensions in Python
# List Compreshensions : It is a shorter syntax to create a new list using values of an existing list.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l = [1,2,3,4,5]
l1 = []
for i in l:
    l1.append(i**2)
print(l1)
# Out:
# [1, 4, 9, 16, 25]

# %%
l2=[i**2 for i in l]

# %%
l2
# Out:
# [1, 4, 9, 16, 25]

# %%
a = [0,1,2,3]
b = [i+1 for i in a]
print(b)
# Out:
# [1, 2, 3, 4]

# %%
[i for i in l if i%2==0]
# Out:
# [2, 4]

# %%
l1 = ['aws','nlp','ml','genai','data science masters']

# %%
[i.upper() for i in l1]
# Out:
# ['AWS', 'NLP', 'ML', 'GENAI', 'DATA SCIENCE MASTERS']

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
list((i**2 for i in l))
# Out:
# [1, 4, 9, 16, 25]

# %%
(i**2 for i in l)
# Out:
# <generator object <genexpr> at 0x000001473D6F69B0>

# %% [markdown]
# ## Set Comprehensions
# It is a shorter synatx to create a new set using values of an existing set.

# %%
a = {0,1,2,4,6}
b = {i ** 2 for i in a}
b
# Out:
# {0, 1, 4, 16, 36}

# %% [markdown]
# ## Dict Comprehensions
# It is a shorter synatx to create a new dictionary using values of an existing dictionary.

# %%
a = {'Hello':'World','First':1}

# %%
b={k:val for k,val in a.items()}

# %%
b
# Out:
# {'Hello': 'World', 'First': 1}

# %%
{val:k for k,val in a.items()}
# Out:
# {'World': 'Hello', 1: 'First'}

# %%
d = {"key1":1 ,"key2":2, "key3":3,"key4":4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}
