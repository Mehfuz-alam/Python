# %% [markdown]
# ## Logging in Python
# Logging allows us to keep track of some events which ocuurs when some software runs.
#
# Levels of Logging
#
# NOTSET
#
# DEBUG
#
# INFO
#
# WARNING
#
# ERROR
#
# CRTICAL

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("This is my print")
# Out:
# This is my print

# %%
import logging

# %%
logging.basicConfig(filename = 'datascience.log', level = logging.INFO)

# %%
logging.info("log the line of execution")

# %%
logging.info("this is my print")

# %%
logging.warning("This is my warning message")

# %%
logging.error("This is my error")
logging.critical("This is my critical message")
logging.debug("This is my message")

# %%
logging.shutdown()

# %%
import logging

# %%
logging.basicConfig(filename= "aws1.log", level= logging.DEBUG, format = '%(asctime)s %(message)s')

# %%
logging.info("This is my info logging")
logging.error("This is my error message")
logging.critical("This is my critical")

# %%
l = [1,2,3,34,4,[2,3,4],'azure','cloud']

# %%
l1_int = []
l2_str = []

for i in l:
    logging.info("we are iterating through our list and our local var is{}".format(l))
    
    if type(i) == list:
        logging.info("I am inside if statement and I am trying to check list type" + str(i))
        for j in i:
            logging.info("I am in another for loop for list inside element" + str(j))
            if type(j) == int:
                logging.info(" I am inside if statment")
                l1_int.append(j)
                
    elif type(i) == int:
            l1_int.append(i)
            
    else :
        if type(i) == str:
            l2_str.append(i)
            
logging.info("my final result for int is {l1} and str is {l2}".format(l1=l1_int , l2=l2_str))

# %%
l1_int
# Out:
# [1, 2, 3, 34, 4, 2, 3, 4]

# %%
l2_str
# Out:
# ['azure', 'cloud']

# %%
#check the datascience.log file
