# %% [markdown]
# ## DICTIONARIES IN PYTHON
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered, changeable or mutable and do not allow duplicates.
#
# Dictionary items are ordered, changeable, and does not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
#
# Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has been created.
#
# Dictionaries cannot have two items with the same key.
# A dictionary can nested and can contain another dictionary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d1 = {'name' : 'Bob'}
print(d1)
# Out:
# {'name': 'Bob'}

# %%
d2 = {'age' : 45}
print(d2)
# Out:
# {'age': 45}

# %%
print(type(d2))
# Out:
# <class 'dict'>

# %%
d3 = {
    'name':'Mehfuz',
    'age':24,
    "email":'alam123mehfuz@gmail.com',
}

# %%
print(d3)
# Out:
# {'name': 'Mehfuz', 'age': 24, 'email': 'alam123mehfuz@gmail.com'}

# %%
d5 = {'course':['deeplearning','machinelearning','nlp','nlp']}
d5
# Out:
# {'course': ['deeplearning', 'machinelearning', 'nlp', 'nlp']}

# %%
d6 = {'key':'youtube','key':'youtube'}
print(d6)
# Out:
# {'key': 'youtube'}

# %%
d6 = {'key':'youtube','key':'youtube1','key':'youtube2'}
print(d6)
# Out:
# {'key': 'youtube2'}

# %%
d3
# Out:
# {'name': 'Mehfuz', 'age': 24, 'email': 'alam123mehfuz@gmail.com'}

# %%
d3['age']
# Out:
# 24

# %%
d3[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 d3[1]
#
# KeyError: 1

# %%
d3['email']
# Out:
# 'alam123mehfuz@gmail.com'

# %%
d7 = {'company':['tata','birla','infosys','ril'],'projects':('ds','ml','nlp'), 'best':'abc'}
d7
# Out:
# {'company': ['tata', 'birla', 'infosys', 'ril'],
#  'projects': ('ds', 'ml', 'nlp'),
#  'best': 'abc'}

# %%
d7['company']
# Out:
# ['tata', 'birla', 'infosys', 'ril']

# %%
d7['company'][1]
# Out:
# 'birla'

# %%
#json format data 

nested_dict = {
    'person':{'name':'john',
            'age':25,
             'address':{'street':'123 Main St',
                       'city':'Farmington',
                       'zipcode':'06032'}}
}

nested_dict
# Out:
# {'person': {'name': 'john',
#   'age': 25,
#   'address': {'street': '123 Main St',
#    'city': 'Farmington',
#    'zipcode': '06032'}}}

# %%
nested_dict['person']
# Out:
# {'name': 'john',
#  'age': 25,
#  'address': {'street': '123 Main St',
#   'city': 'Farmington',
#   'zipcode': '06032'}}

# %%
nested_dict['person']['address']
# Out:
# {'street': '123 Main St', 'city': 'Farmington', 'zipcode': '06032'}

# %%
nested_dict['person']['address']['city']
# Out:
# 'Farmington'

# %%
d8 = {'number' : [2,3,45,67,89], 'assignment':(1,2,3,5,7,8),'course':{'machinelearning':'krish','deeplearning':'youtube','nlp':'udemy'}}
print(d8)
# Out:
# {'number': [2, 3, 45, 67, 89], 'assignment': (1, 2, 3, 5, 7, 8), 'course': {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}}

# %%
d8['course']['machinelearning']
# Out:
# 'krish'

# %% [markdown]
# ## Mutable

# %%
d8['mentor']=['rahul','bob','ruby']

# %%
d8
# Out:
# {'number': [2, 3, 45, 67, 89],
#  'assignment': (1, 2, 3, 5, 7, 8),
#  'course': {'machinelearning': 'krish',
#   'deeplearning': 'youtube',
#   'nlp': 'udemy'},
#  'mentor': ['rahul', 'bob', 'ruby']}

# %% [markdown]
# ## Dict Functions

# %%
dict_keys = d8.keys()

# %%
print(dict_keys)
print(type(dict_keys))
# Out:
# dict_keys(['number', 'assignment', 'course', 'mentor'])
# <class 'dict_keys'>

# %%
d = {}   #empty dict or empty set
print(type(d))
# Out:
# <class 'dict'>

# %%
dict_keys1=list(dict_keys)

# %%
dict_keys1
# Out:
# ['number', 'assignment', 'course', 'mentor']

# %%
print(type(dict_keys1))
# Out:
# <class 'list'>

# %%
print(type(dict_keys))
# Out:
# <class 'dict_keys'>

# %%
d8.values()
# Out:
# dict_values([[2, 3, 45, 67, 89], (1, 2, 3, 5, 7, 8), {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}, ['rahul', 'bob', 'ruby']])

# %%
dict_value=list(d8.values())
print(type(dict_value))
# Out:
# <class 'list'>

# %%
d8.items()
# Out:
# dict_items([('number', [2, 3, 45, 67, 89]), ('assignment', (1, 2, 3, 5, 7, 8)), ('course', {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}), ('mentor', ['rahul', 'bob', 'ruby'])])

# %%
d8.pop('assignment')
# Out:
# (1, 2, 3, 5, 7, 8)

# %%
d8
# Out:
# {'number': [2, 3, 45, 67, 89],
#  'course': {'machinelearning': 'krish',
#   'deeplearning': 'youtube',
#   'nlp': 'udemy'},
#  'mentor': ['rahul', 'bob', 'ruby']}

# %%
d8.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 d8.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d9={1:3,2:4,6:8}

# %%
d9[2]
# Out:
# 4

# %%
d9['6']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 d9['6']
#
# KeyError: '6'

# %%
d9
# Out:
# {1: 3, 2: 4, 6: 8}

# %%
d8
# Out:
# {'number': [2, 3, 45, 67, 89],
#  'course': {'machinelearning': 'krish',
#   'deeplearning': 'youtube',
#   'nlp': 'udemy'},
#  'mentor': ['rahul', 'bob', 'ruby']}

# %%
d8.update(d9)

# %%
d8
# Out:
# {'number': [2, 3, 45, 67, 89],
#  'course': {'machinelearning': 'krish',
#   'deeplearning': 'youtube',
#   'nlp': 'udemy'},
#  'mentor': ['rahul', 'bob', 'ruby'],
#  1: 3,
#  2: 4,
#  6: 8}
