# %% [markdown]
# ## OOPS stands for Object-Oriented Programming System
# ### Classes and Objects
# Class is a Blueprint for that objects or for creating objects.
#
# An Object is simply a collection of data(variables) and methods(function) that acts on those data.
#
# Objects get their variables and function from class.
#
# Objects are nothing but an ecapsulation of variable and function into a single entity.
#
# Self Parameter is a reference to the current instance of the class and is used to access variable that belongs to the class.
#
# All classes have a function called init() which is always executed when the class is being initiated(constructor).
#
# We can use init () function to assign values to object properties or other operations that are necessary to perform when the object is being created.

# %%
a = 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type('aws'))
# Out:
# <class 'str'>

# %%
print(type(1.2356))
# Out:
# <class 'float'>

# %%
class test:   #syntax - to declare a class in python , we need to use 'class' keyword and test-- it is a class name
    pass

# %%
# create a class

class Data:
    num = 3.14
print(Data)
# Out:
# <class '__main__.Data'>

# %%
# create an object 

class Data:
    num = 3.14

obj = Data()  #obj is a object of class Data
obj.num       # to access the class variables we need to use dot operator
# Out:
# 3.14

# %%
a = test()

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class datascience:
    
    
    def welcome_msg(self):  #welcome_msg() -- it is a function or method , self is a reference variable
        print('Welcome To All Our Youtube Channel')

# %%
b=datascience()

# %%
print(type(b))
# Out:
# <class '__main__.datascience'>

# %%
b.welcome_msg()
# Out:
# Welcome To All Our Youtube Channel

# %%
c=datascience()

# %%
c.welcome_msg()
# Out:
# Welcome To All Our Youtube Channel

# %%
class Car:
    def __init__(self,color,model):  #__init__ constructor
        self.color=color
        self.model=model
        
    def start(self):
        return "Engine Started"

# creating an object
my_car=Car("Blue","BMW")

# %%
my_car.color
# Out:
# 'Blue'

# %%
my_car.model
# Out:
# 'BMW'

# %%
my_car.start()
# Out:
# 'Engine Started'

# %%
class infosys:
    def __init__(self,emp_id, emp_name,emp_email_id):
        self.emp_id = emp_id
        self.emp_name = emp_name
        self.emp_email_id = emp_email_id
        
    def return_employee_details(self):
        return self.emp_id, self.emp_name, self.emp_email_id

# %%
obj1 = infosys(101,'rohan','rohan@gmail.com')

# %%
obj1.emp_id
# Out:
# 101

# %%
obj1.emp_name
# Out:
# 'rohan'

# %%
obj1.emp_email_id
# Out:
# 'rohan@gmail.com'

# %%
obj1.return_employee_details()
# Out:
# (101, 'rohan', 'rohan@gmail.com')

# %%
class infosys1:
    def __init__(self,emp_id, emp_name,emp_email_id):
        self.emp_id1 = emp_id
        self.emp_name1 = emp_name
        self.emp_email_id1 = emp_email_id
        
    def return_employee_details(self):
        return self.emp_id1, self.emp_name1, self.emp_email_id1

# %%
obj2 = infosys1(102,'mohan','mohan@gmail.com')

# %%
obj2.emp_id1
# Out:
# 102

# %%
obj2.emp_email_id1
# Out:
# 'mohan@gmail.com'

# %%
obj2.emp_name1
# Out:
# 'mohan'

# %%
obj2.return_employee_details()
# Out:
# (102, 'mohan', 'mohan@gmail.com')

# %%
class infosys2:
    def __init__(aws,emp_id,emp_name,emp_email_id):
        aws.emp_id1 = emp_id
        aws.emp_name1 = emp_name
        aws.emp_email_id1 = emp_email_id
        
        
    def return_employee_details(aws):
        return aws.emp_id1,aws.emp_name1,aws.emp_email_id1

# %%
cloud = infosys2(103,'sohan','sohan@google.com')

# %%
cloud.emp_email_id1
# Out:
# 'sohan@google.com'

# %%
cloud.emp_id1
# Out:
# 103

# %%
cloud.emp_name1
# Out:
# 'sohan'

# %%
cloud.return_employee_details()
# Out:
# (103, 'sohan', 'sohan@google.com')
