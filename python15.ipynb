# %% [markdown]
# ## Encapsulation
# It help in hiding the internal implemenation details of a class and exposing only what is necessary.
#
# Encapsulation is an OOPS concept that binds together the data and functions that manipulate the data, and keeps both safe from outside interference and misuse.
#
# This allows you to modify parts of the implementation without affecting the code that uses the encapsulated classes and methods.
#
# In Python, we can implement encapsulation by using private instance attributes and methods in a class. Private attributes have names starting with double underscores __.

# %%
class test:
    
    def __init__(self,a,b):
        self.a = a
        self.b = b

# %%
t = test(23,24)

# %%
t.a
# Out:
# 23

# %%
t.a = 23456

# %%
t.a
# Out:
# 23456

# %%
class car:
    def __init__(self, year, make , model, speed):
        
        self.__year = year
        self.__make = make
        self.__model = model
        self.__speed = 0
        
    def set_speed(self,speed):
        self.__speed = 0 if speed < 0 else speed
        
    def get_speed(self):
        return self.__speed

# %%
c = car(2021,'maruti','swift',12)

# %%
c.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 c.year
#
# AttributeError: 'car' object has no attribute 'year'

# %%
c._car__year
# Out:
# 2021

# %%
c.set_speed(-320)

# %%
c.get_speed()
# Out:
# 0

# %%
c.set_speed(120)

# %%
c.get_speed()
# Out:
# 120

# %%
class bank_account :
    def __init__(self, balance):
        self.__balance = balance
        
    def deposit(self,amount):
        self.__balance = self.__balance + amount
    
    def withdraw(self,amount):
        if self.__balance >= amount:
            self.__balance = self.__balance - amount 
            return True
        else :
            return False
        
    def get_balance(self):
        return self.__balance

# %%
rohan = bank_account(1000)

# %%
rohan.get_balance()
# Out:
# 1000

# %%
rohan.deposit(5000)

# %%
rohan.get_balance()
# Out:
# 6000

# %%
rohan.withdraw(9000)
# Out:
# False

# %%
rohan.withdraw(2000)
# Out:
# True

# %%
rohan.get_balance()
# Out:
# 4000

# %%
rohan.deposit(10000)

# %%
rohan.get_balance()
# Out:
# 14000
